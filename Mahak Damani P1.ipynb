# %% [markdown]
# Assignment : Analyzing sales Data of ElectroGadget Pvt. Ltd.

# %%
#Import library
import pandas as pd

# %%
# read dataset
df = pd.read_csv('https://github.com/YBIFoundation/Pandas/raw/refs/heads/main/ElectroGadget.csv')

# %%
# info data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderID         500 non-null    object
#  1   Product         500 non-null    object
#  2   Category        500 non-null    object
#  3   Units Sold      500 non-null    int64
#  4   Price Per Unit  500 non-null    int64
#  5   Revenue         500 non-null    int64
#  6   Region          500 non-null    object
#  7   SaleDate        500 non-null    object
# dtypes: int64(3), object(5)
# memory usage: 31.4+ KB

# %%
df.columns
# Out:
# Index(['OrderID', 'Product', 'Category', 'Units Sold', 'Price Per Unit',
#        'Revenue', 'Region', 'SaleDate'],
#       dtype='object')

# %%
df.head(6)
# Out:
#   OrderID     Product     Category  Units Sold  Price Per Unit  Revenue  \
# 0  ORD001       Mouse  Accessories           3            1254     3762
# 1  ORD002     Charger  Accessories           6             748     4488
# 2  ORD003  Headphones  Accessories           4            1034     4136
# 3  ORD004      Tablet  Electronics           2             913     1826
# 4  ORD005  Smartphone  Electronics           3             869     2607
# 5  ORD006      Tablet  Electronics           2            1505     3010
#
#   Region    SaleDate
# 0   East  10-01-2023
# 1  South  04-02-2023
# 2  North  17-01-2023
# 3  South  15-01-2023
# 4   West  20-02-2023
# 5   West  24-02-2023

# %%
df.tail(8)
# Out:
#     OrderID     Product     Category  Units Sold  Price Per Unit  Revenue  \
# 492  ORD493       Mouse  Accessories           8            1164     9312
# 493  ORD494     Charger  Accessories           8            1497    11976
# 494  ORD495     Monitor  Electronics           8             424     3392
# 495  ORD496       Mouse  Accessories           8             477     3816
# 496  ORD497       Mouse  Accessories           5            1097     5485
# 497  ORD498  Smartphone  Electronics           4            1419     5676
# 498  ORD499      Tablet  Electronics           5             905     4525
# 499  ORD500      Laptop  Electronics           4             378     1512
#
#     Region    SaleDate
# 492  North  19-01-2023
# 493  South  06-02-2023
# 494  North  20-01-2023
# 495  North  12-02-2023
# 496  South  04-02-2023
# 497  North  20-02-2023
# 498   East  22-02-2023
# 499  South  04-01-2023

# %%
# Question 1.1: Smartphone with more than 5 units sold
df.query("Product =='Smartphone' and `Units Sold` > 5")
# Out:
#     OrderID     Product     Category  Units Sold  Price Per Unit  Revenue  \
# 28   ORD029  Smartphone  Electronics           9            1331    11979
# 72   ORD073  Smartphone  Electronics           7             618     4326
# 78   ORD079  Smartphone  Electronics           6            1945    11670
# 82   ORD083  Smartphone  Electronics          10            1962    19620
# 88   ORD089  Smartphone  Electronics           8             557     4456
# 169  ORD170  Smartphone  Electronics           8             446     3568
# 170  ORD171  Smartphone  Electronics           7             992     6944
# 173  ORD174  Smartphone  Electronics           7             707     4949
# 213  ORD214  Smartphone  Electronics           6            1343     8058
# 214  ORD215  Smartphone  Electronics           8            1997    15976
# 236  ORD237  Smartphone  Electronics           7            1941    13587
# 247  ORD248  Smartphone  Electronics           7            1520    10640
# ...

# %%
# Question 1.2: Smartphone with more than 5 units sold
df.query("Product =='Smartphone' and `Units Sold` > 5").describe()
# Out:
#        Units Sold  Price Per Unit       Revenue
# count   25.000000       25.000000     25.000000
# mean     7.840000     1215.440000   9531.240000
# std      1.404754      632.236907   5424.192584
# min      6.000000      330.000000   2292.000000
# 25%      7.000000      618.000000   4949.000000
# 50%      8.000000     1331.000000   8058.000000
# 75%      9.000000     1917.000000  13587.000000
# max     10.000000     1997.000000  19820.000000

# %%
# Question 2: Sales in 'Accessories' Category with Revenue > 5000
df.query("Category =='Accessories' and Revenue > 5000")
# Out:
#     OrderID     Product     Category  Units Sold  Price Per Unit  Revenue  \
# 18   ORD019    Keyboard  Accessories           8             861     6888
# 19   ORD020  Headphones  Accessories          10            1251    12510
# 25   ORD026      Webcam  Accessories           8            1147     9176
# 26   ORD027     Charger  Accessories           7             998     6986
# 34   ORD035     Charger  Accessories           9             989     8901
# ..      ...         ...          ...         ...             ...      ...
# 488  ORD489       Mouse  Accessories           5            1129     5645
# 489  ORD490       Mouse  Accessories           4            1406     5624
# 492  ORD493       Mouse  Accessories           8            1164     9312
# 493  ORD494     Charger  Accessories           8            1497    11976
# 496  ORD497       Mouse  Accessories           5            1097     5485
#
#     Region    SaleDate
# 18    West  09-01-2023
# 19    West  29-01-2023
# ...

# %% [markdown]
# Using OR with three conditions
# # Question 3: Show transactions where:
# Product is Tablet
# OR Units Sold >5
# Or Region is East

# %%
df.query("Product == 'Tablet' or `Units Sold`> 5 or Region == 'East'")
# Out:
#     OrderID  Product     Category  Units Sold  Price Per Unit  Revenue Region  \
# 0    ORD001    Mouse  Accessories           3            1254     3762   East
# 1    ORD002  Charger  Accessories           6             748     4488  South
# 3    ORD004   Tablet  Electronics           2             913     1826  South
# 5    ORD006   Tablet  Electronics           2            1505     3010   West
# 6    ORD007   Tablet  Electronics           5             667     3335   West
# ..      ...      ...          ...         ...             ...      ...    ...
# 492  ORD493    Mouse  Accessories           8            1164     9312  North
# 493  ORD494  Charger  Accessories           8            1497    11976  South
# 494  ORD495  Monitor  Electronics           8             424     3392  North
# 495  ORD496    Mouse  Accessories           8             477     3816  North
# 498  ORD499   Tablet  Electronics           5             905     4525   East
#
#        SaleDate
# ...

# %%
# Question 4:
df[ (df['Region']=='East') & (df['Product']=='Tablet') ]
# Out:
#     OrderID Product     Category  Units Sold  Price Per Unit  Revenue Region  \
# 60   ORD061  Tablet  Electronics           5            1800     9000   East
# 77   ORD078  Tablet  Electronics           4             819     3276   East
# 109  ORD110  Tablet  Electronics           3            1859     5577   East
# 167  ORD168  Tablet  Electronics           2             694     1388   East
# 256  ORD257  Tablet  Electronics           4            1065     4260   East
# 337  ORD338  Tablet  Electronics           3             380     1140   East
# 340  ORD341  Tablet  Electronics           2            1640     3280   East
# 365  ORD366  Tablet  Electronics           4            1842     7368   East
# 431  ORD432  Tablet  Electronics           9            1356    12204   East
# 490  ORD491  Tablet  Electronics           7             534     3738   East
# 498  ORD499  Tablet  Electronics           5             905     4525   East
#
#        SaleDate
# 60   10-01-2023
# ...

# %%
# Question 5: Using df.loc() to apply given condition and show selected columns
df.loc[(df['Region']=='North') & (df['Product']=='Charger'),['OrderID','Region', 'Product'] ]
# Out:
#     OrderID Region  Product
# 22   ORD023  North  Charger
# 47   ORD048  North  Charger
# 149  ORD150  North  Charger
# 307  ORD308  North  Charger
# 336  ORD337  North  Charger
# 345  ORD346  North  Charger
# 362  ORD363  North  Charger
# 417  ORD418  North  Charger
# 445  ORD446  North  Charger
# 476  ORD477  North  Charger

# %%
# Question 6: Using df.iloc() to show selected 20 rows and 7 columns
df.iloc[ 121:141 , 1:7]
# Out:
#         Product     Category  Units Sold  Price Per Unit  Revenue Region
# 121  Smartphone  Electronics           5            1442     7210  South
# 122     Monitor  Electronics           5            1668     8340   West
# 123      Laptop  Electronics           5            1340     6700   East
# 124      Webcam  Accessories           7            1462    10234   East
# 125    Keyboard  Accessories           6              45      270  North
# 126      Tablet  Electronics           8            1887    15096   West
# 127    Keyboard  Accessories           4            1194     4776  North
# 128  Smartphone  Electronics           4            1637     6548  North
# 129      Webcam  Accessories           3            1400     4200   West
# 130     Monitor  Electronics           7            1996    13972  North
# 131     Monitor  Electronics           8            1275    10200   East
# 132  Headphones  Accessories           2             655     1310  South
# ...
